# %%
import numpy as np
from utils.recurrence import intertemporal_recurrence_matrix
import pandas as pd

# %%
data = pd.read_csv('data/Norm1.csv', skiprows=1, usecols=[0])

# %%
recurrence_matrix = intertemporal_recurrence_matrix(data[:400])
# Out:
# D:\timegan\WGAN-IRP\utils\recurrence.py:10: RuntimeWarning: invalid value encountered in log
#   inter_recurrence_matrix[i, j] = np.log(data[i] / data[j])

# %%
recurrence_matrix.shape
# Out:
# (400, 400)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(num=None, figsize=((20,20)), dpi= 100)
plt.imshow(recurrence_matrix, cmap = 'binary')
plt.xticks([])
plt.yticks([])
plt.savefig('IRP3')
